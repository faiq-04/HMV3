# %%
# Install dependencies
# %pip install firebase-admin xgboost scikit-learn pandas numpy joblib schedule
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: firebase-admin in d:\laiba\anaconda3\envs\tf\lib\site-packages (7.1.0)
# Requirement already satisfied: xgboost in d:\laiba\anaconda3\envs\tf\lib\site-packages (2.1.4)
# Requirement already satisfied: scikit-learn in d:\laiba\anaconda3\envs\tf\lib\site-packages (1.6.1)
# Requirement already satisfied: pandas in d:\laiba\anaconda3\envs\tf\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy in d:\laiba\anaconda3\envs\tf\lib\site-packages (1.26.4)
# Requirement already satisfied: joblib in d:\laiba\anaconda3\envs\tf\lib\site-packages (1.5.0)
# Requirement already satisfied: schedule in d:\laiba\anaconda3\envs\tf\lib\site-packages (1.2.2)
# Requirement already satisfied: cachecontrol>=0.14.3 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from firebase-admin) (0.14.3)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.25.1 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (2.28.1)
# Requirement already satisfied: google-cloud-firestore>=2.21.0 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from firebase-admin) (2.22.0)
# Requirement already satisfied: google-cloud-storage>=3.1.1 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from firebase-admin) (3.7.0)
# Requirement already satisfied: pyjwt>=2.10.1 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from pyjwt[crypto]>=2.10.1->firebase-admin) (2.10.1)
# Requirement already satisfied: httpx==0.28.1 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from httpx[http2]==0.28.1->firebase-admin) (0.28.1)
# Requirement already satisfied: anyio in d:\laiba\anaconda3\envs\tf\lib\site-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (4.6.2)
# Requirement already satisfied: certifi in d:\laiba\anaconda3\envs\tf\lib\site-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in d:\laiba\anaconda3\envs\tf\lib\site-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (1.0.2)
# Requirement already satisfied: idna in d:\laiba\anaconda3\envs\tf\lib\site-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (3.7)
# Requirement already satisfied: h2<5,>=3 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from httpx[http2]==0.28.1->firebase-admin) (4.3.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (6.33.2)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (1.27.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (2.38.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (2.32.3)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (1.76.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (4.7.2)
# Requirement already satisfied: typing-extensions~=4.12 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from grpcio<2.0.0,>=1.33.2->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (4.12.2)
# Requirement already satisfied: hyperframe<7,>=6.1 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from h2<5,>=3->httpx[http2]==0.28.1->firebase-admin) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from h2<5,>=3->httpx[http2]==0.28.1->firebase-admin) (4.1.0)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from httpcore==1.*->httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (2.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (0.4.8)
# Requirement already satisfied: scipy in d:\laiba\anaconda3\envs\tf\lib\site-packages (from xgboost) (1.13.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: msgpack<2.0.0,>=0.5.2 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from cachecontrol>=0.14.3->firebase-admin) (1.1.2)
# Requirement already satisfied: google-cloud-core<3.0.0,>=1.4.1 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from google-cloud-firestore>=2.21.0->firebase-admin) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from google-cloud-storage>=3.1.1->firebase-admin) (2.8.0)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from google-cloud-storage>=3.1.1->firebase-admin) (1.8.0)
# Requirement already satisfied: cryptography>=3.4.0 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from pyjwt[crypto]>=2.10.1->firebase-admin) (41.0.3)
# Requirement already satisfied: cffi>=1.12 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->firebase-admin) (1.17.1)
# Requirement already satisfied: pycparser in d:\laiba\anaconda3\envs\tf\lib\site-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->firebase-admin) (2.21)
# Requirement already satisfied: six>=1.5 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from anyio->httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in d:\laiba\anaconda3\envs\tf\lib\site-packages (from anyio->httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (1.2.0)
# WARNING: Ignoring invalid distribution -ensorflow (d:\laiba\anaconda3\envs\tf\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (d:\laiba\anaconda3\envs\tf\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (d:\laiba\anaconda3\envs\tf\lib\site-packages)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# How to firebase keyy??

# %% [markdown]
# Step by step to get Firebase service account key:
#
# Go to: https://console.firebase.google.com
#
# Click your existing project (the one with your 2 apps + website)
#
# Click the ⚙️ gear icon (top left, next to project name)
#
# Click "Project Settings"
#
# Click the "Service Accounts" tab
#
# Click the blue "Generate New Private Key" button
#
# A JSON file downloads to your computer

# %%
#Import and setup fire base no need to upload like in canva
import firebase_admin
from firebase_admin import credentials, firestore
import pandas as pd
import numpy as np
import joblib
from datetime import datetime, timedelta
import schedule
import time
import os

def findFirebaseKey():
    startPath = os.path.abspath('../../')  # Go up 2 folders
    for root, dirs, files in os.walk(startPath):
        if 'healmind-2025-firebase-adminsdk-fbsvc-12242dbda6.json' in files:
            return os.path.join(root, 'healmind-2025-firebase-adminsdk-fbsvc-12242dbda6.json')
    raise FileNotFoundError("Firebase key not found!")

cred_path = findFirebaseKey()
cred = credentials.Certificate(cred_path)

try:
    firebase_admin.initialize_app(cred)
except ValueError:
    pass

db = firestore.client()
print(f"Firebase initialized! Found key at: {cred_path}")
# Out:
# An error occurred: module 'importlib.metadata' has no attribute 'packages_distributions'
# d:\laiba\anaconda3\envs\TF\lib\site-packages\google\api_core\_python_version_support.py:237: FutureWarning: You are using a non-supported Python version (3.9.18). Google will not post any further updates to google.api_core supporting this Python version. Please upgrade to the latest Python version, or at least Python 3.10, and then update google.api_core.
#   warnings.warn(message, FutureWarning)
# Firebase initialized! Found key at: d:\laiba\Desktop\USM\CAT304W Drafts\Working\HealMind_ver2\healmind-2025-firebase-adminsdk-fbsvc-12242dbda6.json

# %%
import joblib
import os

# Find the model files
def findFiles(filename):
    startPath = os.path.abspath('../../')
    for root, dirs, files in os.walk(startPath):
        if filename in files:
            return os.path.join(root, filename)
    raise FileNotFoundError(f"{filename} not found!")

# Load model
try:
    modelPath = findFiles('stress_model.pkl')
    model = joblib.load(modelPath)
    print(f"loaded model from {modelPath}")
except Exception as e:
    print(f"error loading model: {e}")
    model = None

# Load scaler
try:
    scalerPath = findFiles('scaler.pkl')
    scaler = joblib.load(scalerPath)
    print(f"loaded scaler from {scalerPath}")
except Exception as e:
    print(f"error loading scaler: {e}")
    scaler = None

if model and scaler:
    print("Files loaded successfully.")
else:
    print("Error: Model or scaler not loaded properly.")
# Out:
# loaded model from d:\laiba\Desktop\USM\CAT304W Drafts\Working\HealMind_ver2\HRVModule\XGBoost\stress_model.pkl
# loaded scaler from d:\laiba\Desktop\USM\CAT304W Drafts\Working\HealMind_ver2\HRVModule\XGBoost\scaler.pkl
# Files loaded successfully.

# %%
# Batch prediction class
class StressPredictor:
    def __init__(self, model, scaler, db):
        self.model = model
        self.scaler = scaler
        self.db = db
        self.feature_names = ['sdnn', 'rmssd']

    def fetch_unprocessed_data(self, hours=1):
        cutoff_time = datetime.utcnow() - timedelta(hours=hours)

        query = self.db.collection('heart_rate_data') \
            .where('timestamp', '>=', cutoff_time) \
            .stream()

        data_points = []
        for doc in query:
            data = doc.to_dict()
            data['doc_id'] = doc.id
            data_points.append(data)

        return pd.DataFrame(data_points) if data_points else pd.DataFrame()

    def group_by_window(self, df, window_minutes=5):
        if df.empty:
            return []

        df['timestamp'] = pd.to_datetime(df['timestamp'])
        df = df.sort_values('timestamp')

        windows = []
        for i in range(0, len(df), window_minutes * 12):
            window = df.iloc[i:i+window_minutes*12]
            if len(window) >= 3:
                windows.append(window)

        return windows

    def process_window(self, window):
        all_ibi = []
        for ibi_list in window['ibi'].dropna():
            if ibi_list:
                all_ibi.extend(ibi_list)

        if not all_ibi or len(all_ibi) < 2:
            return None

        ibi = np.array(all_ibi, dtype=float)
        sdnn = np.std(ibi)
        rmssd = np.sqrt(np.mean(np.diff(ibi) ** 2))

        X = np.array([[sdnn, rmssd]])
        X_scaled = self.scaler.transform(X)

        prediction = self.model.predict(X_scaled)[0]
        probability = self.model.predict_proba(X_scaled)[0]

        return {
            'stress_level': int(prediction),
            'stress_probabilities': {
                'class_0': float(probability[0]),
                'class_1': float(probability[1]) if len(probability) > 1 else 0.0
            },
            'sdnn': float(sdnn),
            'rmssd': float(rmssd),
            'window_start': window['timestamp'].min(),
            'window_end': window['timestamp'].max(),
            'prediction_timestamp': datetime.utcnow(),
            'num_samples': len(window)
        }

    def store_predictions(self, results):
        batch = self.db.batch()

        for result in results:
            doc_ref = self.db.collection('stress_predictions').document()
            batch.set(doc_ref, result)

        batch.commit()
        return len(results)

    def run_batch(self, hours=1):
        print(f"\n{'='*60}")
        print(f"BATCH JOB: {datetime.utcnow().strftime('%Y-%m-%d %H:%M:%S')}")
        print(f"{'='*60}")

        try:
            print(f"Fetching data from last {hours} hour(s)...")
            df = self.fetch_unprocessed_data(hours=hours)

            if df.empty:
                print("No new data to process")
                return

            print(f"Loaded {len(df)} data points")

            windows = self.group_by_window(df)
            print(f"Created {len(windows)} time windows")

            results = []
            for i, window in enumerate(windows):
                result = self.process_window(window)
                if result:
                    results.append(result)

            print(f"Processed {len(results)} windows")

            if results:
                stored = self.store_predictions(results)
                print(f"Stored {stored} predictions to Firestore")

                stress_high = sum(1 for r in results if r['stress_level'] == 1)
                avg_prob = np.mean([r['stress_probabilities']['class_1'] for r in results])
                print(f"\nSummary:")
                print(f"  High stress: {stress_high}/{len(results)}")
                print(f"  Avg probability: {avg_prob:.2%}")

            print(f"{'='*60}\n")
            return results

        except Exception as e:
            print(f"Error: {str(e)}")
            return None

# %%
# Batch prediction class
class StressPredictor:
    def __init__(self, model, scaler, db):
        self.model = model
        self.scaler = scaler
        self.db = db
        self.feature_names = ['sdnn', 'rmssd']

    def fetch_unprocessed_data(self, hours=1):
        cutoff_time = datetime.utcnow() - timedelta(hours=hours)

        query = self.db.collection('heart_rate_data') \
            .where('timestamp', '>=', cutoff_time) \
            .stream()

        data_points = []
        for doc in query:
            data = doc.to_dict()
            data['doc_id'] = doc.id
            data_points.append(data)

        return pd.DataFrame(data_points) if data_points else pd.DataFrame()

    def group_by_window(self, df, window_minutes=5):
        if df.empty:
            return []

        df['timestamp'] = pd.to_datetime(df['timestamp'])
        df = df.sort_values('timestamp')

        windows = []
        for i in range(0, len(df), window_minutes * 12):
            window = df.iloc[i:i+window_minutes*12]
            if len(window) >= 3:
                windows.append(window)

        return windows

    def process_window(self, window):
        all_ibi = []
        for ibi_list in window['ibi'].dropna():
            if ibi_list:
                all_ibi.extend(ibi_list)

        if not all_ibi or len(all_ibi) < 2:
            return None

        ibi = np.array(all_ibi, dtype=float)
        sdnn = np.std(ibi)
        rmssd = np.sqrt(np.mean(np.diff(ibi) ** 2))

        X = np.array([[sdnn, rmssd]])
        X_scaled = self.scaler.transform(X)

        prediction = self.model.predict(X_scaled)[0]
        probability = self.model.predict_proba(X_scaled)[0]

        # Map prediction to stress level label
        stress_labels = {0: 'low', 1: 'medium', 2: 'high'}
        
        return {
            'stress_level': int(prediction),
            'stress_label': stress_labels[int(prediction)],
            'stress_probabilities': {
                'class_0_low': float(probability[0]),
                'class_1_medium': float(probability[1]) if len(probability) > 1 else 0.0,
                'class_2_high': float(probability[2]) if len(probability) > 2 else 0.0
            },
            'sdnn': float(sdnn),
            'rmssd': float(rmssd),
            'window_start': window['timestamp'].min(),
            'window_end': window['timestamp'].max(),
            'prediction_timestamp': datetime.utcnow(),
            'num_samples': len(window)
        }

    def store_predictions(self, results):
        batch = self.db.batch()

        for result in results:
            doc_ref = self.db.collection('stress_predictions').document()
            batch.set(doc_ref, result)

        batch.commit()
        return len(results)

    def run_batch(self, hours=1):
        print(f"\n{'='*60}")
        print(f"BATCH JOB: {datetime.utcnow().strftime('%Y-%m-%d %H:%M:%S')}")
        print(f"{'='*60}")

        try:
            print(f"Fetching data from last {hours} hour(s)...")
            df = self.fetch_unprocessed_data(hours=hours)

            if df.empty:
                print("No new data to process")
                return

            print(f"Loaded {len(df)} data points")

            windows = self.group_by_window(df)
            print(f"Created {len(windows)} time windows")

            results = []
            for i, window in enumerate(windows):
                result = self.process_window(window)
                if result:
                    results.append(result)

            print(f"Processed {len(results)} windows")

            if results:
                stored = self.store_predictions(results)
                print(f"Stored {stored} predictions to Firestore")

                # Count each stress level
                stress_low = sum(1 for r in results if r['stress_level'] == 0)
                stress_medium = sum(1 for r in results if r['stress_level'] == 1)
                stress_high = sum(1 for r in results if r['stress_level'] == 2)
                
                # Average probabilities for each class
                avg_prob_low = np.mean([r['stress_probabilities']['class_0_low'] for r in results])
                avg_prob_medium = np.mean([r['stress_probabilities']['class_1_medium'] for r in results])
                avg_prob_high = np.mean([r['stress_probabilities']['class_2_high'] for r in results])
                
                print(f"\nSummary:")
                print(f"  Low stress:    {stress_low}/{len(results)} (avg prob: {avg_prob_low:.2%})")
                print(f"  Medium stress: {stress_medium}/{len(results)} (avg prob: {avg_prob_medium:.2%})")
                print(f"  High stress:   {stress_high}/{len(results)} (avg prob: {avg_prob_high:.2%})")

            print(f"{'='*60}\n")
            return results

        except Exception as e:
            print(f"Error: {str(e)}")
            return None

# %%
    def fetch_unprocessed_data(self, hours=1):
        cutoff_time = datetime.utcnow() - timedelta(hours=hours)

        # FIX THE WARNING: Use FieldFilter
        query = self.db.collection('heart_rate_data') \
            .where(filter=FieldFilter('timestamp', '>=', cutoff_time)) \
            .stream()

        data_points = []
        for doc in query:
            data = doc.to_dict()
            data['doc_id'] = doc.id
            data_points.append(data)

        return pd.DataFrame(data_points) if data_points else pd.DataFrame()

# %%
# Initialize and run 
predictor = StressPredictor(model, scaler, db)

print("Testing batch processor...")
predictor.run_batch(hours=1)
# Out:
# Testing batch processor...
#
# ============================================================
# BATCH JOB: 2026-01-12 21:20:37
# ============================================================
# Fetching data from last 1 hour(s)...
# Loaded 272 data points
# Created 5 time windows
# Processed 2 windows
# d:\laiba\anaconda3\envs\TF\lib\site-packages\google\cloud\firestore_v1\base_collection.py:315: UserWarning: Detected filter using positional arguments. Prefer using the 'filter' keyword argument instead.
#   return query.where(field_path, op_string, value)
# Stored 2 predictions to Firestore
#
# Summary:
#   Low stress:    2/2 (avg prob: 85.22%)
#   Medium stress: 0/2 (avg prob: 11.94%)
#   High stress:   0/2 (avg prob: 2.85%)
# ============================================================
# [{'stress_level': 0,
#   'stress_label': 'low',
#   'stress_probabilities': {'class_0_low': 0.852184534072876,
#    'class_1_medium': 0.11936081945896149,
#    'class_2_high': 0.02845466136932373},
#   'sdnn': 118.4523532902576,
#   'rmssd': 214.32568674799575,
#   'window_start': Timestamp('2026-01-12 21:16:24.360000+0000', tz='UTC'),
#   'window_end': Timestamp('2026-01-12 21:17:57.822000+0000', tz='UTC'),
#   'prediction_timestamp': datetime.datetime(2026, 1, 12, 21, 20, 37, 718965),
#   'num_samples': 60},
#  {'stress_level': 0,
#   'stress_label': 'low',
#   'stress_probabilities': {'class_0_low': 0.852184534072876,
#    'class_1_medium': 0.11936081945896149,
#    'class_2_high': 0.02845466136932373},
#   'sdnn': 118.4523532902576,
#   'rmssd': 214.32568674799575,
#   'window_start': Timestamp('2026-01-12 21:17:57.831000+0000', tz='UTC'),
#   'window_end': Timestamp('2026-01-12 21:17:58.160000+0000', tz='UTC'),
#   'prediction_timestamp': datetime.datetime(2026, 1, 12, 21, 20, 37, 720968),
#   'num_samples': 32}]

# %%
# Schedule to run every 30 minutes
def job():
    predictor.run_batch(hours=1)

schedule.every(1).minutes.do(job)

print("Scheduler started!")
print("Will run predictions every 30 minutes")
print("\nKeep this cell running to continue processing...")
job()
while True:
    schedule.run_pending()
    time.sleep(60)
# Out:
# Scheduler started!
# Will run predictions every 30 minutes
#
# Keep this cell running to continue processing...
#
# ============================================================
# BATCH JOB: 2026-01-12 21:21:54
# ============================================================
# Fetching data from last 1 hour(s)...
# d:\laiba\anaconda3\envs\TF\lib\site-packages\google\cloud\firestore_v1\base_collection.py:315: UserWarning: Detected filter using positional arguments. Prefer using the 'filter' keyword argument instead.
#   return query.where(field_path, op_string, value)
# Loaded 272 data points
# Created 5 time windows
# Processed 2 windows
# Stored 2 predictions to Firestore
#
# Summary:
#   Low stress:    2/2 (avg prob: 85.22%)
#   Medium stress: 0/2 (avg prob: 11.94%)
#   High stress:   0/2 (avg prob: 2.85%)
# ============================================================
#
#
# ============================================================
# BATCH JOB: 2026-01-12 21:21:54
# ============================================================
# Fetching data from last 1 hour(s)...
# d:\laiba\anaconda3\envs\TF\lib\site-packages\google\cloud\firestore_v1\base_collection.py:315: UserWarning: Detected filter using positional arguments. Prefer using the 'filter' keyword argument instead.
#   return query.where(field_path, op_string, value)
# Loaded 272 data points
# Created 5 time windows
# Processed 2 windows
# Stored 2 predictions to Firestore
#
# Summary:
#   Low stress:    2/2 (avg prob: 85.22%)
#   Medium stress: 0/2 (avg prob: 11.94%)
#   High stress:   0/2 (avg prob: 2.85%)
# ============================================================
#
#
# ============================================================
# BATCH JOB: 2026-01-12 21:21:55
# ============================================================
# Fetching data from last 1 hour(s)...
# d:\laiba\anaconda3\envs\TF\lib\site-packages\google\cloud\firestore_v1\base_collection.py:315: UserWarning: Detected filter using positional arguments. Prefer using the 'filter' keyword argument instead.
#   return query.where(field_path, op_string, value)
# Loaded 272 data points
# Created 5 time windows
# Processed 2 windows
# Stored 2 predictions to Firestore
#
# Summary:
#   Low stress:    2/2 (avg prob: 85.22%)
#   Medium stress: 0/2 (avg prob: 11.94%)
#   High stress:   0/2 (avg prob: 2.85%)
# ============================================================
#
#
# ============================================================
# BATCH JOB: 2026-01-12 21:22:55
# ============================================================
# Fetching data from last 1 hour(s)...
# d:\laiba\anaconda3\envs\TF\lib\site-packages\google\cloud\firestore_v1\base_collection.py:315: UserWarning: Detected filter using positional arguments. Prefer using the 'filter' keyword argument instead.
#   return query.where(field_path, op_string, value)
# Loaded 352 data points
# Created 6 time windows
# Processed 3 windows
# Stored 3 predictions to Firestore
#
# Summary:
#   Low stress:    3/3 (avg prob: 85.22%)
#   Medium stress: 0/3 (avg prob: 11.94%)
#   High stress:   0/3 (avg prob: 2.85%)
# ============================================================
#
#
# ============================================================
# BATCH JOB: 2026-01-12 21:22:55
# ============================================================
# Fetching data from last 1 hour(s)...
# d:\laiba\anaconda3\envs\TF\lib\site-packages\google\cloud\firestore_v1\base_collection.py:315: UserWarning: Detected filter using positional arguments. Prefer using the 'filter' keyword argument instead.
#   return query.where(field_path, op_string, value)
# Loaded 352 data points
# Created 6 time windows
# Processed 3 windows
# Stored 3 predictions to Firestore
#
# Summary:
#   Low stress:    3/3 (avg prob: 85.22%)
#   Medium stress: 0/3 (avg prob: 11.94%)
#   High stress:   0/3 (avg prob: 2.85%)
# ============================================================
#
#
# ============================================================
# BATCH JOB: 2026-01-12 21:22:56
# ============================================================
# Fetching data from last 1 hour(s)...
# d:\laiba\anaconda3\envs\TF\lib\site-packages\google\cloud\firestore_v1\base_collection.py:315: UserWarning: Detected filter using positional arguments. Prefer using the 'filter' keyword argument instead.
#   return query.where(field_path, op_string, value)
# Loaded 352 data points
# Created 6 time windows
# Processed 3 windows
# Stored 3 predictions to Firestore
#
# Summary:
#   Low stress:    3/3 (avg prob: 85.22%)
#   Medium stress: 0/3 (avg prob: 11.94%)
#   High stress:   0/3 (avg prob: 2.85%)
# ============================================================
